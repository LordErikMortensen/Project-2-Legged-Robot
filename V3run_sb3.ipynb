# %%
"""
Run stable baselines 3 on quadruped env 
Check the documentation! https://stable-baselines3.readthedocs.io/en/master/
"""
# %load_ext autoreload
# %autoreload 2

import os
from datetime import datetime
# stable baselines 3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3 import PPO, SAC
from stable_baselines3.common.env_util import make_vec_env
# utils
from utils.utils import CheckpointCallback
from utils.file_utils import get_latest_model
# gym environment
from env.quadruped_gym_env import QuadrupedGymEnv


LEARNING_ALG = "PPO" # or "SAC"
LOAD_NN = False # if you want to initialize training with a previous model 
NUM_ENVS = 1    # how many pybullet environments to create for data collection
USE_GPU = False # make sure to install all necessary drivers 

# LEARNING_ALG = "SAC";  USE_GPU = True
# after implementing, you will want to test how well the agent learns with your MDP: 
env_configs = {"motor_control_mode":"PD_CARTESIAN",
               "task_env": "LR_COURSE_TASK", #  "LR_COURSE_TASK",
               "observation_space_mode": "LR_COURSE_OBS"}
env_configs = {}

if USE_GPU and LEARNING_ALG=="SAC":
    gpu_arg = "auto" 
else:
    gpu_arg = "cpu"

if LOAD_NN:
    interm_dir = "./logs/intermediate_models/"
    log_dir = interm_dir + '' # add path
    stats_path = os.path.join(log_dir, "vec_normalize.pkl")
    model_name = get_latest_model(log_dir)

# directory to save policies and normalization parameters
SAVE_PATH = './logs/intermediate_models/'+ datetime.now().strftime("%m%d%y%H%M%S") + '/'
os.makedirs(SAVE_PATH, exist_ok=True)
# checkpoint to save policy network periodically
checkpoint_callback = CheckpointCallback(save_freq=30000, save_path=SAVE_PATH,name_prefix='rl_model', verbose=2)
# create Vectorized gym environment
env = lambda: QuadrupedGymEnv(**env_configs)  
env = make_vec_env(env, monitor_dir=SAVE_PATH,n_envs=NUM_ENVS)
# normalize observations to stabilize learning (why?)
env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=100.)

if LOAD_NN:
    env = lambda: QuadrupedGymEnv()
    env = make_vec_env(env, n_envs=NUM_ENVS)
    env = VecNormalize.load(stats_path, env)

# Multi-layer perceptron (MLP) policy of two layers of size _,_ 
policy_kwargs = dict(net_arch=[256,256])
# What are these hyperparameters? Check here: https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html
n_steps = 4096 
learning_rate = lambda f: 1e-4 
ppo_config = {  "gamma":0.99, 
                "n_steps": int(n_steps/NUM_ENVS), 
                "ent_coef":0.0, 
                "learning_rate":learning_rate, 
                "vf_coef":0.5,
                "max_grad_norm":0.5, 
                "gae_lambda":0.95, 
                "batch_size":128,
                "n_epochs":10, 
                "clip_range":0.2, 
                "clip_range_vf":1,
                "verbose":1, 
                "tensorboard_log":None, 
                "_init_setup_model":True, 
                "policy_kwargs":policy_kwargs,
                "device": gpu_arg}

# What are these hyperparameters? Check here: https://stable-baselines3.readthedocs.io/en/master/modules/sac.html
sac_config={"learning_rate":1e-4,
            "buffer_size":300000,
            "batch_size":256,
            "ent_coef":'auto', 
            "gamma":0.99, 
            "tau":0.005,
            "train_freq":1, 
            "gradient_steps":1,
            "learning_starts": 10000,
            "verbose":1, 
            "tensorboard_log":None,
            "policy_kwargs": policy_kwargs,
            "seed":None, 
            "device": gpu_arg}

if LEARNING_ALG == "PPO":
    model = PPO('MlpPolicy', env, **ppo_config)
elif LEARNING_ALG == "SAC":
    model = SAC('MlpPolicy', env, **sac_config)
else:
    raise ValueError(LEARNING_ALG + 'not implemented')

if LOAD_NN:
    if LEARNING_ALG == "PPO":
        model = PPO.load(model_name, env)
    elif LEARNING_ALG == "SAC":
        model = SAC.load(model_name, env)
    print("\nLoaded model", model_name, "\n")

# Learn and save (may need to train for longer)
model.learn(total_timesteps=1000000, log_interval=1,callback=checkpoint_callback)
# Don't forget to save the VecNormalize statistics when saving the agent
model.save( os.path.join(SAVE_PATH, "rl_model" ) ) 
env.save(os.path.join(SAVE_PATH, "vec_normalize.pkl" )) 
if LEARNING_ALG == "SAC": # save replay buffer 
    model.save_replay_buffer(os.path.join(SAVE_PATH,"off_policy_replay_buffer"))

## CURRENTLY RUNNING PD CARTESIAN + LR_COURSE_TASK + LR_COURSE_OBS
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\Pablo\Desktop\Code_vic\legged_robots\Project-2-Legged-Robot\env\quadruped_gym_env.py:421: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   ang_velz_tracking_reward = 0.5 * dt * np.exp(-1/0.25 (self.robot.GetBaseAngularVelocity()[2] - des_ang_vel_z)*2)
# c:\Users\Pablo\Desktop\Code_vic\legged_robots\Project-2-Legged-Robot\.conda\Lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# c:\Users\Pablo\Desktop\Code_vic\legged_robots\Project-2-Legged-Robot\.conda\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | 0.00317  |
# | time/              |          |
# |    fps             | 126      |
# |    iterations      | 1        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 4096     |
# ---------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 470        |
# |    ep_rew_mean          | 0.00947    |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 2          |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01757972 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -6.32      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0343    |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 1          |
# |    value_loss           | 0.0177     |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | 0.00852     |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 3           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015188826 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0302     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 1           |
# |    value_loss           | 0.00551     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | 0.0113      |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 4           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015130009 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.041      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 1           |
# |    value_loss           | 0.00397     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 463        |
# |    ep_rew_mean          | 0.0109     |
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 5          |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01659872 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | 0.114      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0338    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 1          |
# |    value_loss           | 0.00265    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 479         |
# |    ep_rew_mean          | 0.00995     |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 6           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016916892 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.28       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00843    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0282     |
# |    std                  | 1           |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 0.0111      |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 7           |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018058654 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.736      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0361     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 1           |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# Saving model checkpoint to ./logs/intermediate_models/121623003211/rl_model_30000_steps
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 0.0116      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 8           |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016803246 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -2.83       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0424     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 1           |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 425         |
# |    ep_rew_mean          | 0.0114      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 9           |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.019045623 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -7.37       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0576     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0316     |
# |    std                  | 1           |
# |    value_loss           | 0.000898    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | 0.0117      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 10          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015541088 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -5.21       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0348     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 1           |
# |    value_loss           | 0.000699    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | 0.0115      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 11          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015504364 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -3.61       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0482     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 1.01        |
# |    value_loss           | 0.000615    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 415        |
# |    ep_rew_mean          | 0.0115     |
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 12         |
# |    time_elapsed         | 446        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01631171 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17.1      |
# |    explained_variance   | -7.3       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0312    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0278    |
# |    std                  | 1          |
# |    value_loss           | 0.000496   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 0.0114      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 13          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017009202 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -7.59       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0515     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0294     |
# |    std                  | 1.01        |
# |    value_loss           | 0.000432    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | 0.0103      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 14          |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017686356 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -6.88       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0274     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 1           |
# |    value_loss           | 0.000367    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# Saving model checkpoint to ./logs/intermediate_models/121623003211/rl_model_60000_steps
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 416         |
# |    ep_rew_mean          | 0.0123      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 15          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017522281 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -11.2       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0495     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 1           |
# |    value_loss           | 0.000314    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 0.0115      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 16          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016912505 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -5.26       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0383     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 1           |
# |    value_loss           | 0.000305    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | 0.0113      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 17          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016358543 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -20.7       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0365     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 1           |
# |    value_loss           | 0.00024     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 422         |
# |    ep_rew_mean          | 0.0105      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 18          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017676415 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -13.1       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0227     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0309     |
# |    std                  | 1           |
# |    value_loss           | 0.000216    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | 0.011       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 19          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017557615 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -10.7       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0472     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0327     |
# |    std                  | 1           |
# |    value_loss           | 0.000211    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | 0.0122      |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 20          |
# |    time_elapsed         | 739         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016775295 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -7.47       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0391     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 1           |
# |    value_loss           | 0.00019     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | 0.0111      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 21          |
# |    time_elapsed         | 773         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.018203344 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -4.35       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0619     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0313     |
# |    std                  | 1           |
# |    value_loss           | 0.000173    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# Saving model checkpoint to ./logs/intermediate_models/121623003211/rl_model_90000_steps
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | 0.0117      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 22          |
# |    time_elapsed         | 811         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019018086 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -19.5       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0299     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 1           |
# |    value_loss           | 0.000144    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 451         |
# |    ep_rew_mean          | 0.0133      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 23          |
# |    time_elapsed         | 844         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017537117 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -6.25       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0417     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.999       |
# |    value_loss           | 0.000142    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 440        |
# |    ep_rew_mean          | 0.0145     |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 24         |
# |    time_elapsed         | 883        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01855236 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -4.93      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0141    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.996      |
# |    value_loss           | 0.00014    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | 0.0168      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 25          |
# |    time_elapsed         | 922         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016613439 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -7.07       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.017      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0285     |
# |    std                  | 0.996       |
# |    value_loss           | 0.000124    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 423         |
# |    ep_rew_mean          | 0.0161      |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 26          |
# |    time_elapsed         | 958         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017814815 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -17         |
# |    explained_variance   | -4.26       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0437     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.996       |
# |    value_loss           | 0.000112    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 414        |
# |    ep_rew_mean          | 0.0164     |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 27         |
# |    time_elapsed         | 994        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01778349 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -9.4       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0176    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0315    |
# |    std                  | 0.995      |
# |    value_loss           | 9.36e-05   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 428        |
# |    ep_rew_mean          | 0.0217     |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 28         |
# |    time_elapsed         | 1030       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.01672507 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -17        |
# |    explained_variance   | -19.5      |
# |    learning_rate        | 0.0001     |
# ...
# |    time_elapsed         | 8206        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.018858518 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.049      |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0422     |
# |    std                  | 0.662       |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 917        |
# |    ep_rew_mean          | 1.74       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 237        |
# |    time_elapsed         | 8240       |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.02252623 |
# |    clip_fraction        | 0.274      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -12        |
# |    explained_variance   | 0.454      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0628    |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | -0.0459    |
# |    std                  | 0.661      |
# |    value_loss           | 0.00302    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 916        |
# |    ep_rew_mean          | 1.75       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 238        |
# |    time_elapsed         | 8273       |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.02114752 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -12        |
# |    explained_variance   | 0.414      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0715    |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.0443    |
# |    std                  | 0.659      |
# |    value_loss           | 0.00354    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 923        |
# |    ep_rew_mean          | 1.81       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 239        |
# |    time_elapsed         | 8307       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.01989978 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -12        |
# |    explained_variance   | 0.507      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.075     |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 0.657      |
# |    value_loss           | 0.0035     |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 240         |
# |    time_elapsed         | 8339        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.021746526 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.9       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.064      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0462     |
# |    std                  | 0.655       |
# |    value_loss           | 0.00374     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 912         |
# |    ep_rew_mean          | 1.84        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 241         |
# |    time_elapsed         | 8373        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.019957384 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.9       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0622     |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0448     |
# |    std                  | 0.654       |
# |    value_loss           | 0.00281     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# Saving model checkpoint to ./logs/intermediate_models/121623003211/rl_model_990000_steps
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 912        |
# |    ep_rew_mean          | 1.87       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 242        |
# |    time_elapsed         | 8405       |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.02020007 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -11.9      |
# |    explained_variance   | 0.468      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.043     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.0456    |
# |    std                  | 0.651      |
# |    value_loss           | 0.0037     |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 914        |
# |    ep_rew_mean          | 1.94       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 243        |
# |    time_elapsed         | 8438       |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.02148414 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -11.8      |
# |    explained_variance   | 0.41       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0813    |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.0448    |
# |    std                  | 0.648      |
# |    value_loss           | 0.00294    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 2.04        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 244         |
# |    time_elapsed         | 8472        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.019466985 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0726     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.647       |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# =================================== Save path is ./logs/intermediate_models/121623003211/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 921         |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 245         |
# |    time_elapsed         | 8505        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.019870773 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0813     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.0463     |
# |    std                  | 0.646       |
# |    value_loss           | 0.00426     |
# -----------------------------------------
