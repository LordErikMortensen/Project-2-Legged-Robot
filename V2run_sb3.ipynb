# %%
"""
Run stable baselines 3 on quadruped env 
Check the documentation! https://stable-baselines3.readthedocs.io/en/master/
"""
# %load_ext autoreload
# %autoreload 2

import os
from datetime import datetime
# stable baselines 3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3 import PPO, SAC
from stable_baselines3.common.env_util import make_vec_env
# utils
from utils.utils import CheckpointCallback
from utils.file_utils import get_latest_model
# gym environment
from env.quadruped_gym_env import QuadrupedGymEnv


LEARNING_ALG = "PPO" # or "SAC"
LOAD_NN = False # if you want to initialize training with a previous model 
NUM_ENVS = 1    # how many pybullet environments to create for data collection
USE_GPU = False # make sure to install all necessary drivers 

# LEARNING_ALG = "SAC";  USE_GPU = True
# after implementing, you will want to test how well the agent learns with your MDP: 
env_configs = {"motor_control_mode":"CPG"}
# env_configs = {}

if USE_GPU and LEARNING_ALG=="SAC":
    gpu_arg = "auto" 
else:
    gpu_arg = "cpu"

if LOAD_NN:
    interm_dir = "./logs/intermediate_models/"
    log_dir = interm_dir + '' # add path
    stats_path = os.path.join(log_dir, "vec_normalize.pkl")
    model_name = get_latest_model(log_dir)

# directory to save policies and normalization parameters
SAVE_PATH = './logs/intermediate_models/'+ datetime.now().strftime("%m%d%y%H%M%S") + '/'
os.makedirs(SAVE_PATH, exist_ok=True)
# checkpoint to save policy network periodically
checkpoint_callback = CheckpointCallback(save_freq=30000, save_path=SAVE_PATH,name_prefix='rl_model', verbose=2)
# create Vectorized gym environment
env = lambda: QuadrupedGymEnv(**env_configs)  
env = make_vec_env(env, monitor_dir=SAVE_PATH,n_envs=NUM_ENVS)
# normalize observations to stabilize learning (why?)
env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=100.)

if LOAD_NN:
    env = lambda: QuadrupedGymEnv()
    env = make_vec_env(env, n_envs=NUM_ENVS)
    env = VecNormalize.load(stats_path, env)

# Multi-layer perceptron (MLP) policy of two layers of size _,_ 
policy_kwargs = dict(net_arch=[256,256])
# What are these hyperparameters? Check here: https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html
n_steps = 4096 
learning_rate = lambda f: 1e-4 
ppo_config = {  "gamma":0.99, 
                "n_steps": int(n_steps/NUM_ENVS), 
                "ent_coef":0.0, 
                "learning_rate":learning_rate, 
                "vf_coef":0.5,
                "max_grad_norm":0.5, 
                "gae_lambda":0.95, 
                "batch_size":128,
                "n_epochs":10, 
                "clip_range":0.2, 
                "clip_range_vf":1,
                "verbose":1, 
                "tensorboard_log":None, 
                "_init_setup_model":True, 
                "policy_kwargs":policy_kwargs,
                "device": gpu_arg}

# What are these hyperparameters? Check here: https://stable-baselines3.readthedocs.io/en/master/modules/sac.html
sac_config={"learning_rate":1e-4,
            "buffer_size":300000,
            "batch_size":256,
            "ent_coef":'auto', 
            "gamma":0.99, 
            "tau":0.005,
            "train_freq":1, 
            "gradient_steps":1,
            "learning_starts": 10000,
            "verbose":1, 
            "tensorboard_log":None,
            "policy_kwargs": policy_kwargs,
            "seed":None, 
            "device": gpu_arg}

if LEARNING_ALG == "PPO":
    model = PPO('MlpPolicy', env, **ppo_config)
elif LEARNING_ALG == "SAC":
    model = SAC('MlpPolicy', env, **sac_config)
else:
    raise ValueError(LEARNING_ALG + 'not implemented')

if LOAD_NN:
    if LEARNING_ALG == "PPO":
        model = PPO.load(model_name, env)
    elif LEARNING_ALG == "SAC":
        model = SAC.load(model_name, env)
    print("\nLoaded model", model_name, "\n")

# Learn and save (may need to train for longer)
model.learn(total_timesteps=1000000, log_interval=1,callback=checkpoint_callback)
# Don't forget to save the VecNormalize statistics when saving the agent
model.save( os.path.join(SAVE_PATH, "rl_model" ) ) 
env.save(os.path.join(SAVE_PATH, "vec_normalize.pkl" )) 
if LEARNING_ALG == "SAC": # save replay buffer 
    model.save_replay_buffer(os.path.join(SAVE_PATH,"off_policy_replay_buffer"))

##### CURRENTLY RUNNING CPG, FORWARD LOCOMOTION, DEFAULT EVERYTHING
# Out:
# c:\Users\Pablo\Desktop\Code_vic\legged_robots\Project-2-Legged-Robot\.conda\Lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# c:\Users\Pablo\Desktop\Code_vic\legged_robots\Project-2-Legged-Robot\.conda\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 0.0128   |
# | time/              |          |
# |    fps             | 66       |
# |    iterations      | 1        |
# |    time_elapsed    | 61       |
# |    total_timesteps | 4096     |
# ---------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 0.0279      |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 2           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011326641 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -2.41       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0101     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 0.0233      |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 3           |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011560713 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0204     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.992       |
# |    value_loss           | 0.00576     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | 0.0179      |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 4           |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011905211 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.0408      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0137     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.992       |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.4        |
# |    ep_rew_mean          | 0.00714     |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 5           |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010869722 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.156      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0315     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.994       |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.5        |
# |    ep_rew_mean          | 0.0121      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 6           |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012407098 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.556      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0243     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.993       |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 93.4       |
# |    ep_rew_mean          | 0.0084     |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 7          |
# |    time_elapsed         | 469        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01071232 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -11.3      |
# |    explained_variance   | -1.02      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0241    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0171    |
# |    std                  | 0.993      |
# |    value_loss           | 0.00104    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# Saving model checkpoint to ./logs/intermediate_models/121623001104/rl_model_30000_steps
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 0.0308      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 8           |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012602699 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -3.33       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0536     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.993       |
# |    value_loss           | 0.000702    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 0.0467      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 9           |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013108739 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.199      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0313     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.993       |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 0.0599      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 10          |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011233941 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.542      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0145     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.988       |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 0.0426      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 11          |
# |    time_elapsed         | 744         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011294562 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.00734     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0174     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.986       |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 0.0581      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 12          |
# |    time_elapsed         | 814         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011189175 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.0121     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0344     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.987       |
# |    value_loss           | 0.000868    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 0.0554      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 13          |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011510852 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.0247      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00908    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.983       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 0.0536      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 14          |
# |    time_elapsed         | 945         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013421903 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.06        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0206     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.98        |
# |    value_loss           | 0.0009      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# Saving model checkpoint to ./logs/intermediate_models/121623001104/rl_model_60000_steps
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 0.0312      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 15          |
# |    time_elapsed         | 1011        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013126492 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.352      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0375     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.98        |
# |    value_loss           | 0.000642    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 0.0215      |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 16          |
# |    time_elapsed         | 1075        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013073767 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.42       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0246     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.98        |
# |    value_loss           | 0.000478    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 135       |
# |    ep_rew_mean          | 0.0382    |
# | time/                   |           |
# |    fps                  | 61        |
# |    iterations           | 17        |
# |    time_elapsed         | 1139      |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0132654 |
# |    clip_fraction        | 0.135     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -11.2     |
# |    explained_variance   | -0.906    |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.0143   |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.0217   |
# |    std                  | 0.979     |
# |    value_loss           | 0.000432  |
# ---------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 0.0574      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 18          |
# |    time_elapsed         | 1202        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013091345 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.0186     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00188    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.976       |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 0.0652      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 19          |
# |    time_elapsed         | 1271        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.014663819 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.0514      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0165     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.975       |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 0.0618      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 20          |
# |    time_elapsed         | 1341        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011976758 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0292     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.973       |
# |    value_loss           | 0.000803    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 0.0493      |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 21          |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011402483 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | -0.0341     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.005      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.974       |
# |    value_loss           | 0.000443    |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# Saving model checkpoint to ./logs/intermediate_models/121623001104/rl_model_90000_steps
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 164        |
# |    ep_rew_mean          | 0.0539     |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 22         |
# |    time_elapsed         | 1471       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01163719 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -11.1      |
# |    explained_variance   | -0.157     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0497    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0217    |
# |    std                  | 0.973      |
# |    value_loss           | 0.000405   |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 173        |
# |    ep_rew_mean          | 0.0575     |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 23         |
# |    time_elapsed         | 1538       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01603897 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -11.1      |
# |    explained_variance   | 0.173      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0331    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.971      |
# |    value_loss           | 0.00102    |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 24          |
# |    time_elapsed         | 1608        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012591764 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0371     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.967       |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 25          |
# |    time_elapsed         | 1672        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013601657 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0206     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.965       |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 0.155       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 26          |
# |    time_elapsed         | 1740        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.015731946 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0166     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.965       |
# |    value_loss           | 0.00227     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 27          |
# |    time_elapsed         | 1807        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014394075 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0272     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.965       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | 0.15        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 28          |
# |    time_elapsed         | 1874        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014230413 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0406     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.962       |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ...
# | train/                  |            |
# |    approx_kl            | 0.01687989 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -9.04      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0174    |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.0303    |
# |    std                  | 0.749      |
# |    value_loss           | 0.0755     |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 237         |
# |    time_elapsed         | 13267       |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.017672936 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -9.02       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0123     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.747       |
# |    value_loss           | 0.0765      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 28.8        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 238         |
# |    time_elapsed         | 13317       |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.017985221 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -9.01       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0125      |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.0277     |
# |    std                  | 0.747       |
# |    value_loss           | 0.0765      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 239         |
# |    time_elapsed         | 13366       |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.018672593 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -9          |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0142     |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0781      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 240         |
# |    time_elapsed         | 13415       |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.018456684 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -8.99       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0201      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0863      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 241         |
# |    time_elapsed         | 13464       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.018585308 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -8.99       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0053      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0313     |
# |    std                  | 0.746       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# Saving model checkpoint to ./logs/intermediate_models/121623001104/rl_model_990000_steps
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 963        |
# |    ep_rew_mean          | 29.3       |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 242        |
# |    time_elapsed         | 13513      |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.01730711 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -8.99      |
# |    explained_variance   | 0.707      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.000173  |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.0317    |
# |    std                  | 0.745      |
# |    value_loss           | 0.0912     |
# ----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 243         |
# |    time_elapsed         | 13563       |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.018025845 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -8.99       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0128      |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0758      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 244         |
# |    time_elapsed         | 13612       |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.017034054 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -8.98       |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0156     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.744       |
# |    value_loss           | 0.0844      |
# -----------------------------------------
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# =================================== Save path is ./logs/intermediate_models/121623001104/
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 245         |
# |    time_elapsed         | 13661       |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.019743845 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -8.97       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00911     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.743       |
# |    value_loss           | 0.081       |
# -----------------------------------------
